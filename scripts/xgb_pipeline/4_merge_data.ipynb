# %%
# %cd ../..

# %%
import pandas as pd
from scripts.globals import *

# %%
positive_df = pd.read_csv(f"{XGB_PIPELINE_DIR}/2_positive_data.csv")
positive_df["label"] = 1


negative_df = pd.read_csv(f"{XGB_PIPELINE_DIR}/3_negative_data.csv")
negative_df["label"] = 0

# %%
df = pd.concat([positive_df, negative_df], ignore_index=True)
df.head()

# %%
df.isna().sum()

# %%
df.to_csv(f"{XGB_PIPELINE_DIR}/4_merged_data.csv", index=False)
